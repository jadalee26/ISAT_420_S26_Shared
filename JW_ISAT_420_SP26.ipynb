# %%
print ('Hello World!')
# Out:
# Hello World!

# %%
import pandas as pd

# %%
###pip install geopandas, how to install from juyputer this way or use %pip so the kernel will automatically be selected as the active kernel

# %%
from scipy.stats import pearson3

# %%
import time

# %%
pip install cdsapi ##worked here but not in terminal
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cdsapi ## not found

# %%
import glob

# %%
import cartopy.crs as ccrs

# %%
###/Users/jadawhite/Documents/GitHub/ISAT 420/ISAT_420_S26_Shared/JW_ISAT_420_SP26.ipynb

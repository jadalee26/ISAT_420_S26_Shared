# %%
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import xarray as xr
#
# ModuleNotFoundError: No module named 'xarray'

# %%
ds = xr.load_dataset('../Data/MOD13A3.061_1km_aid0001_latlon_2020_10km.nc')
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File /opt/anaconda3/lib/python3.13/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x16aced800>, ('/Users/jadawhite/Documents/GitHub/ISAT 420/Data/MOD13A3.061_1km_aid0001_latlon_2020_10km.nc',), 'r', (('mmap', None), ('version', 2)), '13162a93-56b6-4c80-b741-f38519295110']
#
# During handling of the above exception, another exception occurred:
#
# ...
